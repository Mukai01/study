# %% [markdown]
# # DataBricksのclusterをAMLにAttachする

# %%
from azureml.core import Workspace
from azureml.core.compute import DatabricksCompute, ComputeTarget

ws = Workspace.from_config("./config")

db_resource_group = "dp100"
db_workspace_name = "Databricks01"
# Access Token は DatabricksのUser Settingsから作成する
db_access_token = "dapi855095b836fa289bf1ecb757dcaaeb94"

db_compute_name = "mydbcluster001"
if db_compute_name not in ws.compute_targets:
    attach_config = DatabricksCompute.attach_configuration(
                                    resource_group=db_resource_group,
                                    workspace_name=db_workspace_name,
                                    access_token=db_access_token)

    db_cluster = ComputeTarget.attach(ws, db_compute_name, attach_config)
    db_cluster.wait_for_completion(True)

else:
    db_cluster = ws.compute_targets[db_compute_name]

# %% [markdown]
# # 設定を行う

# %%
# ------------------------------------------------------
# Run the DatabricksStep as an AzureML Pipeline step
# ------------------------------------------------------
from azureml.core import Workspace

# Access the Workspace
ws = Workspace.from_config("./config")


# -----------------------------------------------------------------
# Create custom environment
# -----------------------------------------------------------------
from azureml.core import Environment
from azureml.core.environment import CondaDependencies

# Create the environment
myenv = Environment(name="MyEnvironment")

# Create the dependencies object
myenv_dep = CondaDependencies.create(conda_packages=['scikit-learn==0.22.1', 'joblib', 'pandas'])

myenv.python.conda_dependencies = myenv_dep

# Register the environment
myenv.register(ws)



# -----------------------------------------------------------------
# Create a compute cluster for pipeline
# -----------------------------------------------------------------
cluster_name = "pipeline-cluster"

# # Provisioning configuration using AmlCompute
from azureml.core.compute import AmlCompute

print("Accessing the compute cluster...")

if cluster_name not in ws.compute_targets:
    print("Creating the compute cluster with name: ", cluster_name)
    compute_config = AmlCompute.provisioning_configuration(
                                      vm_size="STANDARD_D11_V2",
                                      max_nodes=2)

    compute_cluster = AmlCompute.create(ws, cluster_name, compute_config)
    compute_cluster.wait_for_completion()
else:
    compute_cluster = ws.compute_targets[cluster_name]
    print(cluster_name, ", compute cluster found. Using it...")


# -----------------------------------------------------------------
# Create Run Configurations for the steps
# -----------------------------------------------------------------
from azureml.core.runconfig import RunConfiguration
run_config = RunConfiguration()

run_config.target = compute_cluster
run_config.environment = myenv



# -----------------------------------------------------------------
# Attach the Databricks Cluster as an attached compute target
# -----------------------------------------------------------------
from azureml.core.compute    import DatabricksCompute
from azureml.core.compute    import ComputeTarget

# Initialize the attach config parameters
db_resource_group = "dp100"
db_workspace_name = "Databricks01"
# Access Token は DatabricksのUser Settingsから作成する
db_access_token = "dapi855095b836fa289bf1ecb757dcaaeb94"
db_compute_name = "mydbcluster001"


# Attach the Databricks compute target
if db_compute_name not in ws.compute_targets:
    print("Creating attach config for Databricks...")
    attach_config = DatabricksCompute.attach_configuration(
                            resource_group = db_resource_group,
                            workspace_name = db_workspace_name,
                            access_token = db_access_token)
    
    print("Attaching Databricks Cluster to AzureML workspace..")
    db_cluster = ComputeTarget.attach(ws,
                                      db_compute_name,
                                      attach_config)

    db_cluster.wait_for_completion(True)

else:
    print('Compute target already exists')
    db_cluster = ws.compute_targets[db_compute_name]


# -----------------------------------------------------------------
# Create/pass data reference of Input and Output
# -----------------------------------------------------------------
from azureml.data.data_reference import DataReference
from azureml.pipeline.core   import PipelineData

# Create input data reference
# data_store = ws.get_default_datastore()
data_store = ws.datastores.get('azure_sdk_blob01')

input_data = DataReference(datastore = data_store,
                           data_reference_name = 'input')

output_data1 = PipelineData('testdata', datastore=data_store)
# Out:
# Accessing the compute cluster...
# pipeline-cluster , compute cluster found. Using it...
# Compute target already exists

# %% [markdown]
# # Databricksstepを作成する

# %%
# Create the Databricks Step
from azureml.pipeline.steps import DatabricksStep
from azureml.core.databricks import PyPiLibrary

scikit_learn = PyPiLibrary(package = 'scikit-learn==0.22.1')
joblib       = PyPiLibrary(package = 'joblib')


# Databricks ⇒ Cluster ⇒ NotebookからPathを確認可能
notebook_path = r"/Users/nakamukaiya@gmail.com/demo001"

db_step01 = DatabricksStep(name = "db_step01",
                           inputs = [input_data],
                           outputs = [output_data1],
                           num_workers = 1,
                           notebook_path = notebook_path,
                           run_name = "db_notebook_demo",
                           compute_target = db_cluster,
                           pypi_libraries = [scikit_learn, joblib],
                           allow_reuse = False) # Trueにすると、過去のrunを再利用できる

# %%
# Databricks stepでAIの判定を行い、Storageに結果を保存
# eval stepでそれを読み込んで評価を行う
# -----------------------------------------------------------------
# Create the pipeline step to run python script
# ----------------------------------------------------------------
from azureml.pipeline.steps import PythonScriptStep

eval_step    = PythonScriptStep(name='Evaluate',
                                 source_directory='./script',
                                 script_name='630 - Evaluate.py',
                                 inputs=[output_data1],
                                 runconfig=run_config,
                                 arguments=['--testdata', output_data1])

# -----------------------------------------------------------------
# Build and submit the pipeline
# -----------------------------------------------------------------
from azureml.pipeline.core   import Pipeline
from azureml.core            import Experiment

steps             = [db_step01, eval_step]
new_pipeline      = Pipeline(workspace=ws, steps=steps)
new_pipeline_run  = Experiment(ws, 'DB_Notebook_exp001').submit(new_pipeline)

# Wait for completion
new_pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step db_step01 [4549581a][9d56fde7-1c2b-4095-a4e7-ea2ef981f5e3], (This step will run and generate new outputs)
# Created step Evaluate [4cdb7e87][a444d72f-1eca-4210-b2fc-343472bfd354], (This step is eligible to reuse a previous run's output)
# Using data reference input for StepId [e4b09270][5b0dfa0b-94df-4882-add4-43770e66ecb3], (Consumers of this data are eligible to reuse prior runs.)
# Submitted PipelineRun 6a918073-2a09-49cd-abfc-910e3a68651c
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/6a918073-2a09-49cd-abfc-910e3a68651c?wsid=/subscriptions/3467f739-a57b-4612-9de8-72a6616c01b3/resourcegroups/AzuremlSDKRG00/workspaces/Azureml-SDK-WS01&tid=bcd8db96-8bb9-4f0d-af35-e471bf92c072
# PipelineRunId: 6a918073-2a09-49cd-abfc-910e3a68651c
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs
logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=zeWQ9M19FyLDIh4lv4WHYuxK7UiSToDCX4wwbFWOZ5k%3D&skoid=285719f7-ab93-4fe7-a7ba-e7b47a2d53bd&sktid=bcd8db96-8bb9-4f0d-af35-e471bf92c072&skt=2022-10-08T05%3A06%3A45Z&ske=2022-10-09T13%3A16%3A45Z&sks=b&skv=2019-07-07&st=2022-10-08T08%3A51%3A42Z&se=2022-10-08T17%3A01%3A42Z&sp=r'}, 'submittedBy': '保徳 中向'}
#
#
#
#
# StepRunId: 22de851a-d558-47e2-847b-e066855b1518
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/22de851a-d558-47e2-847b-e066855b1518?wsid=/subscriptions/3467f739-a57b-4612-9de8-72a6616c01b3/resourcegroups/AzuremlSDKRG00/workspaces/Azureml-SDK-WS01&tid=bcd8db96-8bb9-4f0d-af35-e471bf92c072
# StepRun( Evaluate ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2022/10/08 09:05:02 Downloading source code...
# 2022/10/08 09:05:03 Finished downloading source code
# 2022/10/08 09:05:03 Creating Docker network: acb_default_network, driver: 'bridge'
# 2022/10/08 09:05:03 Successfully set up Docker network: acb_default_network
# 2022/10/08 09:05:03 Setting up Docker configuration...
# 2022/10/08 09:05:04 Successfully set up Docker configuration
# 2022/10/08 09:05:04 Logging in to registry: 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io
# 2022/10/08 09:05:05 Successfully logged into 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io
# 2022/10/08 09:05:05 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/10/08 09:05:05 Scanning for dependencies...
# 2022/10/08 09:05:05 Successfully scanned dependencies
# 2022/10/08 09:05:05 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/21 : FROM mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220915.v1@sha256:b1f72bf846c3deb803982a2e329b1500b4c796615875105986647e4c7a466f4c
# mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220915.v1@sha256:b1f72bf846c3deb803982a2e329b1500b4c796615875105986647e4c7a466f4c: Pulling from azureml/openmpi4.1.0-ubuntu20.04
# d7bfe07ed847: Already exists
# 464e693656a9: Pulling fs layer
# 8c578bff06c7: Pulling fs layer
# d78f9390ce26: Pulling fs layer
# ba3403859f87: Pulling fs layer
# 262e1eff605a: Pulling fs layer
# 89633e3da997: Pulling fs layer
# 986eeef57cb1: Pulling fs layer
# c07bc2525035: Pulling fs layer
# 2747c6e3d726: Pulling fs layer
# ba3403859f87: Waiting
# 262e1eff605a: Waiting
# 89633e3da997: Waiting
# 986eeef57cb1: Waiting
# c07bc2525035: Waiting
# 2747c6e3d726: Waiting
# d78f9390ce26: Verifying Checksum
# d78f9390ce26: Download complete
# ba3403859f87: Verifying Checksum
# ba3403859f87: Download complete
# 8c578bff06c7: Verifying Checksum
# 8c578bff06c7: Download complete
# 262e1eff605a: Verifying Checksum
# 262e1eff605a: Download complete
# 464e693656a9: Verifying Checksum
# 464e693656a9: Download complete
# c07bc2525035: Verifying Checksum
# c07bc2525035: Download complete
# 2747c6e3d726: Verifying Checksum
# 2747c6e3d726: Download complete
# 986eeef57cb1: Verifying Checksum
# 986eeef57cb1: Download complete
# 89633e3da997: Download complete
# 464e693656a9: Pull complete
# 8c578bff06c7: Pull complete
# d78f9390ce26: Pull complete
# ba3403859f87: Pull complete
# 262e1eff605a: Pull complete
# 89633e3da997: Pull complete
# 986eeef57cb1: Pull complete
# c07bc2525035: Pull complete
# 2747c6e3d726: Pull complete
# Digest: sha256:b1f72bf846c3deb803982a2e329b1500b4c796615875105986647e4c7a466f4c
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220915.v1@sha256:b1f72bf846c3deb803982a2e329b1500b4c796615875105986647e4c7a466f4c
#  ---> ec2fb4f2c94e
# Step 2/21 : USER root
#  ---> Running in 8ff67d3ec0ec
# Removing intermediate container 8ff67d3ec0ec
#  ---> 9c505dcde7a7
# Step 3/21 : RUN mkdir -p $HOME/.cache
#  ---> Running in d38ba5325e31
# Removing intermediate container d38ba5325e31
#  ---> adce400b5b53
# Step 4/21 : WORKDIR /
#  ---> Running in 234ddb084fe9
# Removing intermediate container 234ddb084fe9
#  ---> 1215ca5b67ef
# Step 5/21 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 09ec9f90bdfe
# Step 6/21 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in a33ce89bf520
# Removing intermediate container a33ce89bf520
#  ---> 8175e129a0c6
# Step 7/21 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> d70046b2b26c
# Step 8/21 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_5facbb09c99e77ed568632b31e323952 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 607dd6b4d817
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# scikit-learn-0.22.1  | 7.3 MB    |            |   0%
# scikit-learn-0.22.1  | 7.3 MB    |            |   0%
# scikit-learn-0.22.1  | 7.3 MB    | 2          |   2%
# scikit-learn-0.22.1  | 7.3 MB    | 4          |   5%
# scikit-learn-0.22.1  | 7.3 MB    | 7          |   7%
# scikit-learn-0.22.1  | 7.3 MB    | #2         |  12%
# scikit-learn-0.22.1  | 7.3 MB    | #8         |  19%
# scikit-learn-0.22.1  | 7.3 MB    | ###        |  30%
# scikit-learn-0.22.1  | 7.3 MB    | ####4      |  45%
# scikit-learn-0.22.1  | 7.3 MB    | #####9     |  59%
# scikit-learn-0.22.1  | 7.3 MB    | #########  |  91%
# scikit-learn-0.22.1  | 7.3 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# zlib-1.2.12          | 130 KB    |            |   0%
# zlib-1.2.12          | 130 KB    | ########## | 100%
#
# wheel-0.37.1         | 31 KB     |            |   0%
# wheel-0.37.1         | 31 KB     | ########## | 100%
#
# libgomp-11.2.0       | 560 KB    |            |   0%
# libgomp-11.2.0       | 560 KB    | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# pytz-2022.1          | 243 KB    |            |   0%
# pytz-2022.1          | 243 KB    | ########## | 100%
# pytz-2022.1          | 243 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 5          |   5%
# mkl-2019.4           | 204.1 MB  | #2         |  13%
# mkl-2019.4           | 204.1 MB  | ##         |  21%
# mkl-2019.4           | 204.1 MB  | ##8        |  29%
# mkl-2019.4           | 204.1 MB  | ###6       |  36%
# mkl-2019.4           | 204.1 MB  | ####4      |  44%
# mkl-2019.4           | 204.1 MB  | #####1     |  52%
# mkl-2019.4           | 204.1 MB  | #####9     |  59%
# mkl-2019.4           | 204.1 MB  | ######6    |  66%
# mkl-2019.4           | 204.1 MB  | #######3   |  74%
# mkl-2019.4           | 204.1 MB  | ########   |  81%
# mkl-2019.4           | 204.1 MB  | ########8  |  88%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# _openmp_mutex-5.1    | 20 KB     |            |   0%
# _openmp_mutex-5.1    | 20 KB     | ########## | 100%
#
# mkl_fft-1.3.0        | 195 KB    |            |   0%
# mkl_fft-1.3.0        | 195 KB    | 8          |   8%
# mkl_fft-1.3.0        | 195 KB    | ####1      |  41%
# mkl_fft-1.3.0        | 195 KB    | ########## | 100%
#
# scipy-1.6.2          | 20.1 MB   |            |   0%
# scipy-1.6.2          | 20.1 MB   |            |   0%
# scipy-1.6.2          | 20.1 MB   | 7          |   8%
# scipy-1.6.2          | 20.1 MB   | #2         |  13%
# scipy-1.6.2          | 20.1 MB   | ##         |  21%
# scipy-1.6.2          | 20.1 MB   | ###4       |  35%
# scipy-1.6.2          | 20.1 MB   | #####3     |  53%
# scipy-1.6.2          | 20.1 MB   | ########   |  81%
# scipy-1.6.2          | 20.1 MB   | ########## | 100%
# scipy-1.6.2          | 20.1 MB   | ########## | 100%
#
# setuptools-61.2.0    | 1.3 MB    |            |   0%
# setuptools-61.2.0    | 1.3 MB    | ########## | 100%
# setuptools-61.2.0    | 1.3 MB    | ########## | 100%
#
# mkl-service-2.3.0    | 68 KB     |            |   0%
# mkl-service-2.3.0    | 68 KB     | ########## | 100%
#
# libstdcxx-ng-11.2.0  | 6.1 MB    |            |   0%
# libstdcxx-ng-11.2.0  | 6.1 MB    | ########## | 100%
# libstdcxx-ng-11.2.0  | 6.1 MB    | ########## | 100%
#
# ca-certificates-2022 | 131 KB    |            |   0%
# ca-certificates-2022 | 131 KB    | ########## | 100%
#
# openssl-1.1.1q       | 3.8 MB    |            |   0%
# openssl-1.1.1q       | 3.8 MB    | ########## | 100%
# openssl-1.1.1q       | 3.8 MB    | ########## | 100%
#
# sqlite-3.39.2        | 1.5 MB    |            |   0%
# sqlite-3.39.2        | 1.5 MB    | ########## | 100%
# sqlite-3.39.2        | 1.5 MB    | ########## | 100%
#
# numpy-1.19.2         | 21 KB     |            |   0%
# numpy-1.19.2         | 21 KB     | ########## | 100%
#
# joblib-1.1.0         | 211 KB    |            |   0%
# joblib-1.1.0         | 211 KB    | ########## | 100%
#
# numpy-base-1.19.2    | 5.3 MB    |            |   0%
# numpy-base-1.19.2    | 5.3 MB    | ########## | 100%
# numpy-base-1.19.2    | 5.3 MB    | ########## | 100%
#
# libgcc-ng-11.2.0     | 8.5 MB    |            |   0%
# libgcc-ng-11.2.0     | 8.5 MB    | ########## | 100%
# libgcc-ng-11.2.0     | 8.5 MB    | ########## | 100%
#
# readline-8.1.2       | 423 KB    |            |   0%
# readline-8.1.2       | 423 KB    | ########## | 100%
#
# libffi-3.3           | 54 KB     |            |   0%
# libffi-3.3           | 54 KB     | ########## | 100%
#
# python-dateutil-2.8. | 241 KB    |            |   0%
# python-dateutil-2.8. | 241 KB    | ########## | 100%
#
# certifi-2022.6.15    | 156 KB    |            |   0%
# certifi-2022.6.15    | 156 KB    | ########## | 100%
#
# libgfortran4-7.5.0   | 1.3 MB    |            |   0%
# libgfortran4-7.5.0   | 1.3 MB    | 1          |   1%
# libgfortran4-7.5.0   | 1.3 MB    | ########## | 100%
# libgfortran4-7.5.0   | 1.3 MB    | ########## | 100%
#
# pip-22.1.2           | 2.9 MB    |            |   0%
# pip-22.1.2           | 2.9 MB    | ########## | 100%
# pip-22.1.2           | 2.9 MB    | ########## | 100%
#
# mkl_random-1.1.0     | 398 KB    |            |   0%
# mkl_random-1.1.0     | 398 KB    | ########## | 100%
#
# bottleneck-1.3.5     | 125 KB    |            |   0%
# bottleneck-1.3.5     | 125 KB    | ########## | 100%
#
# intel-openmp-2022.0. | 8.5 MB    |            |   0%
# intel-openmp-2022.0. | 8.5 MB    | ########## | 100%
# intel-openmp-2022.0. | 8.5 MB    | ########## | 100%
#
# six-1.16.0           | 19 KB     |            |   0%
# six-1.16.0           | 19 KB     | ########## | 100%
#
# numexpr-2.7.3        | 196 KB    |            |   0%
# numexpr-2.7.3        | 196 KB    | 8          |   8%
# numexpr-2.7.3        | 196 KB    | ########## | 100%
#
# ld_impl_linux-64-2.3 | 732 KB    |            |   0%
# ld_impl_linux-64-2.3 | 732 KB    | ########## | 100%
# ld_impl_linux-64-2.3 | 732 KB    | ########## | 100%
#
# ncurses-6.3          | 1.1 MB    |            |   0%
# ncurses-6.3          | 1.1 MB    | ########## | 100%
# ncurses-6.3          | 1.1 MB    | ########## | 100%
#
# python-3.8.13        | 22.7 MB   |            |   0%
# python-3.8.13        | 22.7 MB   | #####4     |  55%
# python-3.8.13        | 22.7 MB   | ########## | 100%
#
# xz-5.2.5             | 389 KB    |            |   0%
# xz-5.2.5             | 389 KB    | ########## | 100%
#
# pandas-1.4.3         | 12.6 MB   |            |   0%
# pandas-1.4.3         | 12.6 MB   | #######6   |  76%
# pandas-1.4.3         | 12.6 MB   | ########## | 100%
#
# tk-8.6.12            | 3.3 MB    |            |   0%
# tk-8.6.12            | 3.3 MB    | ########## | 100%
# tk-8.6.12            | 3.3 MB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_5facbb09c99e77ed568632b31e323952/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.uqsirjq2.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.46.0
#   Downloading azureml_defaults-1.46.0-py3-none-any.whl (2.0 kB)
# Collecting azureml-inference-server-http~=0.7.2
#   Downloading azureml_inference_server_http-0.7.6-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 11.9 MB/s eta 0:00:00
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.46.0
#   Downloading azureml_dataset_runtime-1.46.0-py3-none-any.whl (2.3 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting azureml-core~=1.46.0
#   Downloading azureml_core-1.46.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 114.6 MB/s eta 0:00:00
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<38.0.0
#   Downloading cryptography-37.0.4-cp36-abi3-manylinux_2_24_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 35.2 MB/s eta 0:00:00
# Collecting knack~=0.9.0
#   Downloading knack-0.9.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 13.9 MB/s eta 0:00:00
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 14.9 MB/s eta 0:00:00
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-1.0.0-py2.py3-none-any.whl (19 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.5.0-py3-none-any.whl (20 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.2/146.2 kB 34.0 MB/s eta 0:00:00
# Collecting urllib3<2.0.0,>=1.23
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 kB 28.3 MB/s eta 0:00:00
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.20.0-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 21.9 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /azureml-envs/azureml_5facbb09c99e77ed568632b31e323952/lib/python3.8/site-packages (from azureml-core~=1.46.0->azureml-defaults~=1.46.0->-r /azureml-environment-setup/condaenv.uqsirjq2.requirements.txt (line 1)) (2022.1)
# Collecting azure-core<2.0.0
#   Downloading azure_core-1.26.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 40.7 MB/s eta 0:00:00
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.10.1-py3-none-any.whl (27 kB)
# Collecting azure-mgmt-resource<22.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-21.1.0-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 100.6 MB/s eta 0:00:00
# Collecting pkginfo
#   Downloading pkginfo-1.8.3-py2.py3-none-any.whl (26 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 13.1 MB/s eta 0:00:00
# Collecting packaging<22.0,>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 8.5 MB/s eta 0:00:00
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting azure-mgmt-keyvault<11.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-10.1.0-py3-none-any.whl (605 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.9/605.9 kB 81.7 MB/s eta 0:00:00
# Collecting jmespath<2.0.0
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting azure-mgmt-authorization<3,>=0.40.0
#   Downloading azure_mgmt_authorization-2.0.0-py2.py3-none-any.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.2/465.2 kB 68.9 MB/s eta 0:00:00
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.4/141.4 kB 21.3 MB/s eta 0:00:00
# Collecting azure-mgmt-containerregistry<11,>=8.2.0
#   Downloading azure_mgmt_containerregistry-10.0.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 102.9 MB/s eta 0:00:00
# Collecting msrest<=0.7.1,>=0.5.1
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_5facbb09c99e77ed568632b31e323952/lib/python3.8/site-packages (from azureml-core~=1.46.0->azureml-defaults~=1.46.0->-r /azureml-environment-setup/condaenv.uqsirjq2.requirements.txt (line 1)) (2.8.2)
# Collecting argcomplete<3
#   Downloading argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting humanfriendly<11.0,>=4.7
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 20.2 MB/s eta 0:00:00
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 6.9 MB/s eta 0:00:00
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.11.0-py2.py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 42.4 MB/s eta 0:00:00
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.2.0-py2.py3-none-any.whl (39 kB)
# Collecting pyopenssl<23.0.0
#   Downloading pyOpenSSL-22.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 11.9 MB/s eta 0:00:00
# Collecting azure-mgmt-storage<=20.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-20.0.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 120.3 MB/s eta 0:00:00
# Collecting azureml-dataprep<4.6.0a,>=4.5.0a
#   Downloading azureml_dataprep-4.5.7-py3-none-any.whl (43.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 MB 67.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.19.3 in /azureml-envs/azureml_5facbb09c99e77ed568632b31e323952/lib/python3.8/site-packages (from azureml-dataset-runtime[fuse]~=1.46.0->azureml-defaults~=1.46.0->-r /azureml-environment-setup/condaenv.uqsirjq2.requirements.txt (line 1)) (1.19.2)
# Collecting pyarrow<=9.0.0,>=0.17.0
#   Downloading pyarrow-9.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 75.8 MB/s eta 0:00:00
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting flask<2.2.0
#   Downloading Flask-2.1.3-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.6/95.6 kB 21.4 MB/s eta 0:00:00
# Collecting inference-schema~=1.4.0
#   Downloading inference_schema-1.4.2.1-py3-none-any.whl (21 kB)
# Collecting opencensus-ext-azure~=1.1.0
#   Downloading opencensus_ext_azure-1.1.7-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 10.0 MB/s eta 0:00:00
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 18.0 MB/s eta 0:00:00
# Collecting flask-cors~=3.0.1
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_5facbb09c99e77ed568632b31e323952/lib/python3.8/site-packages (from gunicorn==20.1.0->azureml-inference-server-http~=0.7.2->azureml-defaults~=1.46.0->-r /azureml-environment-setup/condaenv.uqsirjq2.requirements.txt (line 1)) (61.2.0)
# Collecting typing-extensions>=4.0.1
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_5facbb09c99e77ed568632b31e323952/lib/python3.8/site-packages (from azure-core<2.0.0->azureml-core~=1.46.0->azureml-defaults~=1.46.0->-r /azureml-environment-setup/condaenv.uqsirjq2.requirements.txt (line 1)) (1.16.0)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.2-py3-none-any.whl (26 kB)
# Collecting azureml-dataprep-rslex~=2.11.0dev0
#   Downloading azureml_dataprep_rslex-2.11.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 116.1 MB/s eta 0:00:00
# Collecting pyyaml<7.0.0,>=5.1.0
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.2/701.2 kB 82.2 MB/s eta 0:00:00
# Collecting cloudpickle<3.0.0,>=1.1.0
#   Downloading cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp38-cp38-manylinux1_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 109.7 MB/s eta 0:00:00
# Collecting jsonschema
#   Downloading jsonschema-4.16.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 15.7 MB/s eta 0:00:00
# Collecting dotnetcore2<4.0.0,>=3.0.0
#   Downloading dotnetcore2-3.1.23-py3-none-manylinux1_x86_64.whl (31.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.1/31.1 MB 83.7 MB/s eta 0:00:00
# Collecting azure-identity==1.7.0
#   Downloading azure_identity-1.7.0-py2.py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 29.3 MB/s eta 0:00:00
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-0.3.1-py2.py3-none-any.whl (18 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.7/442.7 kB 67.7 MB/s eta 0:00:00
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.4.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.0/55.0 kB 14.0 MB/s eta 0:00:00
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting Jinja2>=3.0
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 29.2 MB/s eta 0:00:00
# Collecting click>=8.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 21.4 MB/s eta 0:00:00
# Collecting importlib-metadata>=3.6.0
#   Downloading importlib_metadata-5.0.0-py3-none-any.whl (21 kB)
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 39.7 MB/s eta 0:00:00
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting pygments
#   Downloading Pygments-2.13.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 98.2 MB/s eta 0:00:00
# Collecting portalocker<3,>=1.0
#   Downloading portalocker-2.5.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_5facbb09c99e77ed568632b31e323952/lib/python3.8/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.46.0->azureml-defaults~=1.46.0->-r /azureml-environment-setup/condaenv.uqsirjq2.requirements.txt (line 1)) (2022.6.15)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 9.0 MB/s eta 0:00:00
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 17.9 MB/s eta 0:00:00
# Collecting opencensus<1.0.0,>=0.11.0
#   Downloading opencensus-0.11.0-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 24.7 MB/s eta 0:00:00
# Collecting psutil>=5.6.3
#   Downloading psutil-5.9.2-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (284 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.8/284.8 kB 52.2 MB/s eta 0:00:00
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 22.8 MB/s eta 0:00:00
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 89.7 MB/s eta 0:00:00
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-4.0.0-cp36-abi3-manylinux_2_28_x86_64.whl (594 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.4/594.4 kB 83.9 MB/s eta 0:00:00
# Collecting pyopenssl<23.0.0
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 12.7 MB/s eta 0:00:00
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 15.3 MB/s eta 0:00:00
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 12.5 MB/s eta 0:00:00
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 27.2 MB/s eta 0:00:00
# Collecting distro>=1.2.0
#   Downloading distro-1.7.0-py3-none-any.whl (20 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.8.1-py3-none-any.whl (5.6 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting opencensus-context>=0.1.3
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting google-api-core<3.0.0,>=1.0.0
#   Downloading google_api_core-2.10.2-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.6/115.6 kB 22.4 MB/s eta 0:00:00
# Collecting types-cryptography>=3.3.21
#   Downloading types_cryptography-3.3.23-py3-none-any.whl (30 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.1-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 28.1 MB/s eta 0:00:00
# Collecting importlib-resources>=1.4.0
#   Downloading importlib_resources-5.10.0-py3-none-any.whl (34 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 13.5 MB/s eta 0:00:00
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.18.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 kB 26.2 MB/s eta 0:00:00
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Downloading googleapis_common_protos-1.56.4-py2.py3-none-any.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.7/211.7 kB 46.7 MB/s eta 0:00:00
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5
#   Downloading protobuf-4.21.7-cp37-abi3-manylinux2014_x86_64.whl (408 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.4/408.4 kB 53.5 MB/s eta 0:00:00
# Collecting google-auth<3.0dev,>=1.25.0
#   Downloading google_auth-2.12.0-py2.py3-none-any.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.8/169.8 kB 41.1 MB/s eta 0:00:00
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 29.5 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=d9fb2939da0d8936ea3aec23800b51f3106a1b8c74ee21df170f42aabbdfd54c
#   Stored in directory: /root/.cache/pip/wheels/e9/d6/70/7491901d808e74dd9238e4a91658ba108e4b5939b55327e6fb
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=34406e6bc97a21b35fe1af5fb3e707f137086c6e8a3ce3eafd8cafecab7880b4
#   Stored in directory: /root/.cache/pip/wheels/7f/41/10/f70b83a1164fdb95e7bc37bace13114a024227e56c2fee02bb
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp38-cp38-linux_x86_64.whl size=81713 sha256=98ea58354ae72fa9ba12daca0d2ee7ff32c4a86936a9e843f6af096e6c1c14be
#   Stored in directory: /root/.cache/pip/wheels/5f/fd/9e/b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73
# Successfully built json-logging-py fusepy wrapt
# Installing collected packages: wrapt, types-cryptography, pyasn1, opencensus-context, json-logging-py, fusepy, backports.weakref, azureml-dataprep-rslex, azureml-dataprep-native, azure-common, zipp, websocket-client, urllib3, typing-extensions, tabulate, rsa, pyyaml, PySocks, pyrsistent, pyparsing, PyJWT, pygments, pycparser, pyasn1-modules, pyarrow, psutil, protobuf, portalocker, pkgutil-resolve-name, pkginfo, pathspec, oauthlib, MarkupSafe, jsonpickle, jmespath, jeepney, itsdangerous, isodate, idna, humanfriendly, gunicorn, distro, contextlib2, configparser, cloudpickle, click, charset-normalizer, cachetools, bcrypt, backports.tempfile, attrs, argcomplete, Werkzeug, requests, packaging, knack, Jinja2, inference-schema, importlib-resources, importlib-metadata, googleapis-common-protos, google-auth, dotnetcore2, cffi, requests-oauthlib, pynacl, jsonschema, google-api-core, flask, docker, cryptography, azure-core, SecretStorage, pyopenssl, paramiko, opencensus, msrest, flask-cors, azure-mgmt-core, adal, ndg-httpsclient, msrestazure, msal, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, msal-extensions, azure-graphrbac, azureml-core, azure-identity, opencensus-ext-azure, azureml-dataprep, azureml-inference-server-http, azureml-dataset-runtime, azureml-defaults
# Successfully installed Jinja2-3.1.2 MarkupSafe-2.1.1 PyJWT-2.5.0 PySocks-1.7.1 SecretStorage-3.3.3 Werkzeug-2.2.2 adal-1.2.7 argcomplete-2.0.0 attrs-22.1.0 azure-common-1.1.28 azure-core-1.26.0 azure-graphrbac-0.61.1 azure-identity-1.7.0 azure-mgmt-authorization-2.0.0 azure-mgmt-containerregistry-10.0.0 azure-mgmt-core-1.3.2 azure-mgmt-keyvault-10.1.0 azure-mgmt-resource-21.1.0 azure-mgmt-storage-20.0.0 azureml-core-1.46.0 azureml-dataprep-4.5.7 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.11.4 azureml-dataset-runtime-1.46.0 azureml-defaults-1.46.0 azureml-inference-server-http-0.7.6 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-4.0.0 cachetools-5.2.0 cffi-1.15.1 charset-normalizer-2.1.1 click-8.1.3 cloudpickle-2.2.0 configparser-3.7.4 contextlib2-21.6.0 cryptography-37.0.4 distro-1.7.0 docker-5.0.3 dotnetcore2-3.1.23 flask-2.1.3 flask-cors-3.0.10 fusepy-3.0.1 google-api-core-2.10.2 google-auth-2.12.0 googleapis-common-protos-1.56.4 gunicorn-20.1.0 humanfriendly-10.0 idna-3.4 importlib-metadata-5.0.0 importlib-resources-5.10.0 inference-schema-1.4.2.1 isodate-0.6.1 itsdangerous-2.1.2 jeepney-0.8.0 jmespath-1.0.1 json-logging-py-0.2 jsonpickle-2.2.0 jsonschema-4.16.0 knack-0.9.0 msal-1.20.0 msal-extensions-0.3.1 msrest-0.7.1 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.2.1 opencensus-0.11.0 opencensus-context-0.1.3 opencensus-ext-azure-1.1.7 packaging-21.3 paramiko-2.11.0 pathspec-0.10.1 pkginfo-1.8.3 pkgutil-resolve-name-1.3.10 portalocker-2.5.1 protobuf-4.21.7 psutil-5.9.2 pyarrow-9.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.21 pygments-2.13.0 pynacl-1.5.0 pyopenssl-22.0.0 pyparsing-3.0.9 pyrsistent-0.18.1 pyyaml-6.0 requests-2.28.1 requests-oauthlib-1.3.1 rsa-4.9 tabulate-0.9.0 types-cryptography-3.3.23 typing-extensions-4.4.0 urllib3-1.26.12 websocket-client-1.4.1 wrapt-1.12.1 zipp-3.8.1
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_5facbb09c99e77ed568632b31e323952
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 607dd6b4d817
#  ---> 3bb469ac5de7
# Step 9/21 : ENV PATH /azureml-envs/azureml_5facbb09c99e77ed568632b31e323952/bin:$PATH
#  ---> Running in 5e526332c7e4
# Removing intermediate container 5e526332c7e4
#  ---> 139c64903dac
# Step 10/21 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> ca5d0975ab3a
# Step 11/21 : RUN echo "Copying environment context"
#  ---> Running in 9fca6ea6093e
# Copying environment context
# Removing intermediate container 9fca6ea6093e
#  ---> a74b1df8b741
# Step 12/21 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 60411d7aa267
# Step 13/21 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_5facbb09c99e77ed568632b31e323952
#  ---> Running in 773c6dccb062
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 773c6dccb062
#  ---> ceadf93fd6c2
# Step 14/21 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_5facbb09c99e77ed568632b31e323952
#  ---> Running in 64fce7d77abb
# Removing intermediate container 64fce7d77abb
#  ---> d466eea4a749
# Step 15/21 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_5facbb09c99e77ed568632b31e323952/lib:$LD_LIBRARY_PATH
#  ---> Running in 2e2c25d06f9f
# Removing intermediate container 2e2c25d06f9f
#  ---> 31d75e593d7f
# Step 16/21 : ENV CONDA_DEFAULT_ENV=azureml_5facbb09c99e77ed568632b31e323952 CONDA_PREFIX=/azureml-envs/azureml_5facbb09c99e77ed568632b31e323952
#  ---> Running in f355853f7e6b
# Removing intermediate container f355853f7e6b
#  ---> 6cb66b853f9b
# Step 17/21 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 183b985c0bf8
# Step 18/21 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 3efac561f336
# Removing intermediate container 3efac561f336
#  ---> 4a157dd7554f
# Step 19/21 : RUN rm -rf azureml-environment-setup
#  ---> Running in 610a8d705144
# Removing intermediate container 610a8d705144
#  ---> d7012f4cc3da
# Step 20/21 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in b3cfc6d65f43
# Removing intermediate container b3cfc6d65f43
#  ---> a9c447d17503
# Step 21/21 : CMD ["bash"]
#  ---> Running in 6e8ea4976303
# Removing intermediate container 6e8ea4976303
#  ---> abfc12c7c268
# Successfully built abfc12c7c268
# Successfully tagged 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io/azureml/azureml_58592a1761384ef162426c9ee03369f1:latest
# Successfully tagged 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io/azureml/azureml_58592a1761384ef162426c9ee03369f1:1
# 2022/10/08 09:08:49 Successfully executed container: acb_step_0
# 2022/10/08 09:08:49 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/10/08 09:08:49 Pushing image: 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io/azureml/azureml_58592a1761384ef162426c9ee03369f1:1, attempt 1
# The push refers to repository [27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io/azureml/azureml
# b577f3ea5a1a: Waiting
# 4dbf5f708d91: Waiting
# 61086b4dd729: Waiting
# 339cc9230658: Waiting
# 65cb687f36fa: Waiting
# 899c8cd37a1c: Waiting
# d1210ad29f1f: Waiting
# 4f5029a9dd35: Waiting
# af7ed92504ae: Waiting
# d97a0d4cdf00: Waiting
# b32fd4f1d73b: Layer already exists
# d32b5a37f1bf: Layer already exists
# 38f00ea547b6: Layer already exists
# 9ae119768de2: Layer already exists
# 448e6ffa1c66: Layer already exists
# bc7e4b17e4cd: Layer already exists
# 4deaf29ab7d1: Layer already exists
# 61086b4dd729: Layer already exists
# 899c8cd37a1c: Layer already exists
# 4f5029a9dd35: Layer already exists
# 5db58646e2f5: Layer already exists
# c52612c14feb: Layer already exists
# b577f3ea5a1a: Layer already exists
# 4dbf5f708d91: Layer already exists
# d97a0d4cdf00: Layer already exists
# 339cc9230658: Layer already exists
# 65cb687f36fa: Layer already exists
# 94f2f8deda61: Layer already exists
# af7ed92504ae: Layer already exists
# d1210ad29f1f: Layer already exists
# latest: digest: sha256:459584d1574b83d904d68e0769e70397915f59dd7695e503d79e5829ce1faa34 size: 4513
# 2022/10/08 09:10:26 Successfully pushed image: 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io/azureml/azureml_58592a1761384ef162426c9ee03369f1:latest
# 2022/10/08 09:10:26 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 224.173298)
# 2022/10/08 09:10:26 Populating digests for step ID: acb_step_0...
# 2022/10/08 09:10:27 Successfully populated digests for step ID: acb_step_0
# 2022/10/08 09:10:27 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 95.334989)
# 2022/10/08 09:10:27 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.376582)
# 2022/10/08 09:10:27 The following dependencies were found:
# 2022/10/08 09:10:27
# - image:
#     registry: 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io
#     repository: azureml/azureml_58592a1761384ef162426c9ee03369f1
#     tag: latest
#     digest: sha256:459584d1574b83d904d68e0769e70397915f59dd7695e503d79e5829ce1faa34
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20220915.v1
#     digest: sha256:b1f72bf846c3deb803982a2e329b1500b4c796615875105986647e4c7a466f4c
#   git: {}
# - image:
#     registry: 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io
#     repository: azureml/azureml_58592a1761384ef162426c9ee03369f1
#     tag: "1"
#     digest: sha256:459584d1574b83d904d68e0769e70397915f59dd7695e503d79e5829ce1faa34
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20220915.v1
#     digest: sha256:b1f72bf846c3deb803982a2e329b1500b4c796615875105986647e4c7a466f4c
#   git: {}
# Run ID: cea was successful after 5m25s
# Unable to stream download: ("Connection broken: ConnectionResetError(10054, '既存の接続はリモート ホストに強制的に切断されました。', None, 10054, None)", ConnectionResetError(10054, '既存の接続はリモート ホストに強制的に切断されました。', None, 10054, None))
# StepRun(Evaluate) Execution Summary
# ====================================
# StepRun( Evaluate ) Status: Finished
# {'runId': '22de851a-d558-47e2-847b-e066855b1518', 'target': 'pipeline-cluster', 'status': 'Completed', 'startTimeUtc': '2022-10-08T09:17:42.214714Z', 'endTimeUtc': '2022-10-08T09:19:28.579657Z', 'services': {}, 'properties': {'ContentSnapshotId': '91a371df-af0a-4894-986b-953a5e3ab8de', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'a444d72f-1eca-4210-b2fc-343472bfd354', 'azureml.moduleName': 'Evaluate', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '4cdb7e87', 'azureml.pipelinerunid': '6a918073-2a09-49cd-abfc-910e3a68651c', 'azureml.pipeline': '6a918073-2a09-49cd-abfc-910e3a68651c', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'am