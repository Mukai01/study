# %% [markdown]
# # DataBricksのclusterをAMLにAttachする

# %%
from azureml.core import Workspace
from azureml.core.compute import DatabricksCompute, ComputeTarget

ws = Workspace.from_config("./config")

db_resource_group = "dp100"
db_workspace_name = "Databricks01"
# Access Token は DatabricksのUser Settingsから作成する
db_access_token = "dapi855095b836fa289bf1ecb757dcaaeb94"

db_compute_name = "mydbcluster001"
if db_compute_name not in ws.compute_targets:
    attach_config = DatabricksCompute.attach_configuration(
                                    resource_group=db_resource_group,
                                    workspace_name=db_workspace_name,
                                    access_token=db_access_token)

    db_cluster = ComputeTarget.attach(ws, db_compute_name, attach_config)
    db_cluster.wait_for_completion(True)

else:
    db_cluster = ws.compute_targets[db_compute_name]

# %% [markdown]
# # 設定を行う

# %%
# ------------------------------------------------------
# Run the DatabricksStep as an AzureML Pipeline step
# ------------------------------------------------------
from azureml.core import Workspace

# Access the Workspace
ws = Workspace.from_config("./config")


# -----------------------------------------------------------------
# Create custom environment
# -----------------------------------------------------------------
from azureml.core import Environment
from azureml.core.environment import CondaDependencies

# Create the environment
myenv = Environment(name="MyEnvironment")

# Create the dependencies object
myenv_dep = CondaDependencies.create(conda_packages=['scikit-learn', 'joblib', 'pandas'])

myenv.python.conda_dependencies = myenv_dep

# Register the environment
myenv.register(ws)



# -----------------------------------------------------------------
# Create a compute cluster for pipeline
# -----------------------------------------------------------------
cluster_name = "pipeline-cluster"

# # Provisioning configuration using AmlCompute
from azureml.core.compute import AmlCompute

print("Accessing the compute cluster...")

if cluster_name not in ws.compute_targets:
    print("Creating the compute cluster with name: ", cluster_name)
    compute_config = AmlCompute.provisioning_configuration(
                                      vm_size="STANDARD_D11_V2",
                                      max_nodes=2)

    compute_cluster = AmlCompute.create(ws, cluster_name, compute_config)
    compute_cluster.wait_for_completion()
else:
    compute_cluster = ws.compute_targets[cluster_name]
    print(cluster_name, ", compute cluster found. Using it...")


# -----------------------------------------------------------------
# Create Run Configurations for the steps
# -----------------------------------------------------------------
from azureml.core.runconfig import RunConfiguration
run_config = RunConfiguration()

run_config.target = compute_cluster
run_config.environment = myenv



# -----------------------------------------------------------------
# Attach the Databricks Cluster as an attached compute target
# -----------------------------------------------------------------
from azureml.core.compute    import DatabricksCompute
from azureml.core.compute    import ComputeTarget

# Initialize the attach config parameters
db_resource_group = "dp100"
db_workspace_name = "Databricks01"
# Access Token は DatabricksのUser Settingsから作成する
db_access_token = "dapi855095b836fa289bf1ecb757dcaaeb94"
db_compute_name = "mydbcluster001"


# Attach the Databricks compute target
if db_compute_name not in ws.compute_targets:
    print("Creating attach config for Databricks...")
    attach_config = DatabricksCompute.attach_configuration(
                            resource_group = db_resource_group,
                            workspace_name = db_workspace_name,
                            access_token = db_access_token)
    
    print("Attaching Databricks Cluster to AzureML workspace..")
    db_cluster = ComputeTarget.attach(ws,
                                      db_compute_name,
                                      attach_config)

    db_cluster.wait_for_completion(True)

else:
    print('Compute target already exists')
    db_cluster = ws.compute_targets[db_compute_name]


# -----------------------------------------------------------------
# Create/pass data reference of Input and Output
# -----------------------------------------------------------------
from azureml.data.data_reference import DataReference
from azureml.pipeline.core   import PipelineData

# Create input data reference
# data_store = ws.get_default_datastore()
data_store = ws.datastores.get('azure_sdk_blob01')

input_data = DataReference(datastore = data_store,
                           data_reference_name = 'input')

output_data1 = PipelineData('testdata', datastore=data_store)
# Out:
# Accessing the compute cluster...
# pipeline-cluster , compute cluster found. Using it...
# Compute target already exists

# %% [markdown]
# # Databricksstepを作成する

# %%
# Create the Databricks Step
from azureml.pipeline.steps import DatabricksStep
from azureml.core.databricks import PyPiLibrary

scikit_learn = PyPiLibrary(package = 'scikit-learn')
joblib       = PyPiLibrary(package = 'joblib')


# Databricks ⇒ Cluster ⇒ NotebookからPathを確認可能
notebook_path = r"/Users/nakamukaiya@gmail.com/demo001"

db_step01 = DatabricksStep(name = "db_step01",
                           inputs = [input_data],
                           outputs = [output_data1],
                           num_workers = 1,
                           notebook_path = notebook_path,
                           run_name = "db_notebook_demo",
                           compute_target = db_cluster,
                           pypi_libraries = [scikit_learn, joblib],
                           allow_reuse = False) # Trueにすると、過去のrunを再利用できる

# %%
# Databricks stepでAIの判定を行い、Storageに結果を保存
# eval stepでそれを読み込んで評価を行う
# -----------------------------------------------------------------
# Create the pipeline step to run python script
# ----------------------------------------------------------------
from azureml.pipeline.steps import PythonScriptStep

eval_step    = PythonScriptStep(name='Evaluate',
                                 source_directory='./script',
                                 script_name='630 - Evaluate.py',
                                 inputs=[output_data1],
                                 runconfig=run_config,
                                 arguments=['--testdata', output_data1])

# -----------------------------------------------------------------
# Build and submit the pipeline
# -----------------------------------------------------------------
from azureml.pipeline.core   import Pipeline
from azureml.core            import Experiment

steps             = [db_step01, eval_step]
new_pipeline      = Pipeline(workspace=ws, steps=steps)
new_pipeline_run  = Experiment(ws, 'DB_Notebook_exp001').submit(new_pipeline)

# Wait for completion
new_pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step db_step01 [720f1a26][73435178-c871-4eeb-a0e4-c097e7d31a8d], (This step will run and generate new outputs)
# Created step Evaluate [61366517][70931347-1ce4-4ab9-9728-2df1d39e7e0e], (This step is eligible to reuse a previous run's output)
# Using data reference input for StepId [0e5b692f][5b0dfa0b-94df-4882-add4-43770e66ecb3], (Consumers of this data are eligible to reuse prior runs.)
# Submitted PipelineRun af7da592-2d0b-4aa1-8666-fc313786c580
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/af7da592-2d0b-4aa1-8666-fc313786c580?wsid=/subscriptions/3467f739-a57b-4612-9de8-72a6616c01b3/resourcegroups/AzuremlSDKRG00/workspaces/Azureml-SDK-WS01&tid=bcd8db96-8bb9-4f0d-af35-e471bf92c072
# PipelineRunId: af7da592-2d0b-4aa1-8666-fc313786c580
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/af7da592-2d0b-4aa1-8666-fc313786c580?wsid=/subscriptions/3467f739-a57b-4612-9de8-72a6616c01b3/resourcegroups/AzuremlSDKRG00/workspaces/Azureml-SDK-WS01&tid=bcd8db96-8bb9-4f0d-af35-e471bf92c072
# PipelineRun Status: Running
#
#
# StepRunId: 5192c843-7a9c-4c25-be32-8e48da275e39
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/5192c843-7a9c-4c25-be32-8e48da275e39?wsid=/subscriptions/3467f739-a57b-4612-9de8-72a6616c01b3/resourcegroups/AzuremlSDKRG00/workspaces/Azureml-SDK-WS01&tid=bcd8db96-8bb9-4f0d-af35-e471bf92c072
# StepRun( db_step01 ) Status: Running
#
# StepRun(db_step01) Execution Summary
# =====================================
# StepRun( db_step01 ) Status: Finished
# {'runId': '5192c843-7a9c-4c25-be32-8e48da275e39', 'target': 'mydbcluster001', 'status': 'Completed', 'startTimeUtc': '2022-10-08T06:44:29.92763Z', 'endTimeUtc': '2022-10-08T06:49:21.784467Z', 'services': {}, 'properties': {'ContentSnapshotId': '9dc5e6c6-3886-41d7-bd1f-1d254950f184', 'StepType': 'DataBricksStep', 'ComputeTargetType': 'DataBricks', 'azureml.moduleid': '73435178-c871-4eeb-a0e4-c097e7d31a8d', 'azureml.moduleName': 'db_step01', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '720f1a26', 'azureml.pipelinerunid': 'af7da592-2d0b-4aa1-8666-fc313786c580', 'azureml.pipeline': 'af7da592-2d0b-4aa1-8666-fc313786c580', 'azureml.pipelineComponent': 'masterdatabrickscloud', 'azureml.joblink': 'https://adb-6582459807600029.9.azuredatabricks.net/?o=6582459807600029#job/279424540415609/run/6953'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://azuremlsstorage74437b7d7.blob.core.windows.net/azureml/ExperimentRun/dcid.5192c843-7a9c-4c25-be32-8e48da275e39/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=9HklXzqkVU2wKQpdElylSyXYHkcgjE1qkHkhtvXihWQ%3D&skoid=285719f7-ab93-4fe7-a7ba-e7b47a2d53bd&sktid=bcd8db96-8bb9-4f0d-af35-e471bf92c072&skt=2022-10-08T05%3A06%3A45Z&ske=2022-10-09T13%3A16%3A45Z&sks=b&skv=2019-07-07&st=2022-10-08T06%3A34%3A31Z&se=2022-10-08T14%3A44%3A31Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://azuremlsstorage74437b7d7.blob.core.windows.net/azureml/ExperimentRun/dcid.5192c843-7a9c-4c25-be32-8e48da275e39/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=fSLVhXIq0N2NDoaMVqNJ2f0XcJPWvPFTdCXH4yWEopw%3D&skoid=285719f7-ab93-4fe7-a7ba-e7b47a2d53bd&sktid=bcd8db96-8bb9-4f0d-af35-e471bf92c072&skt=2022-10-08T05%3A06%3A45Z&ske=2022-10-09T13%3A16%3A45Z&sks=b&skv=2019-07-07&st=2022-10-08T06%3A34%3A31Z&se=2022-10-08T14%3A44%3A31Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://azuremlsstorage74437b7d7.blob.core.windows.net/azureml/ExperimentRun/dcid.5192c843-7a9c-4c25-be32-8e48da275e39/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=g6HRpvSLOAHIZZACdc28%2FsNEd%2Fg2DX%2FLUR6I1KP1OcM%3D&skoid=285719f7-ab93-4fe7-a7ba-e7b47a2d53bd&sktid=bcd8db96-8bb9-4f0d-af35-e471bf92c072&skt=2022-10-08T05%3A06%3A45Z&ske=2022-10-09T13%3A16%3A45Z&sks=b&skv=2019-07-07&st=2022-10-08T06%3A34%3A31Z&se=2022-10-08T14%3A44%3A31Z&sp=r'}, 'submittedBy': '保徳 中向'}
#
#
#
#
# StepRunId: bade5400-f521-482d-a0dc-360b14eac72c
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/bade5400-f521-482d-a0dc-360b14eac72c?wsid=/subscriptions/3467f739-a57b-4612-9de8-72a6616c01b3/resourcegroups/AzuremlSDKRG00/workspaces/Azureml-SDK-WS01&tid=bcd8db96-8bb9-4f0d-af35-e471bf92c072
# StepRun( Evaluate ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2022/10/08 06:49:29 Downloading source code...
# 2022/10/08 06:49:30 Finished downloading source code
# 2022/10/08 06:49:30 Creating Docker network: acb_default_network, driver: 'bridge'
# 2022/10/08 06:49:30 Successfully set up Docker network: acb_default_network
# 2022/10/08 06:49:30 Setting up Docker configuration...
# 2022/10/08 06:49:31 Successfully set up Docker configuration
# 2022/10/08 06:49:31 Logging in to registry: 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io
# 2022/10/08 06:49:32 Successfully logged into 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io
# 2022/10/08 06:49:32 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/10/08 06:49:32 Scanning for dependencies...
# 2022/10/08 06:49:32 Successfully scanned dependencies
# 2022/10/08 06:49:32 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/21 : FROM mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220915.v1@sha256:b1f72bf846c3deb803982a2e329b1500b4c796615875105986647e4c7a466f4c
# mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220915.v1@sha256:b1f72bf846c3deb803982a2e329b1500b4c796615875105986647e4c7a466f4c: Pulling from azureml/openmpi4.1.0-ubuntu20.04
# d7bfe07ed847: Already exists
# 464e693656a9: Pulling fs layer
# 8c578bff06c7: Pulling fs layer
# d78f9390ce26: Pulling fs layer
# ba3403859f87: Pulling fs layer
# 262e1eff605a: Pulling fs layer
# 89633e3da997: Pulling fs layer
# 986eeef57cb1: Pulling fs layer
# c07bc2525035: Pulling fs layer
# 2747c6e3d726: Pulling fs layer
# ba3403859f87: Waiting
# 262e1eff605a: Waiting
# 89633e3da997: Waiting
# 986eeef57cb1: Waiting
# c07bc2525035: Waiting
# 2747c6e3d726: Waiting
# d78f9390ce26: Verifying Checksum
# d78f9390ce26: Download complete
# 8c578bff06c7: Verifying Checksum
# 8c578bff06c7: Download complete
# ba3403859f87: Verifying Checksum
# ba3403859f87: Download complete
# 89633e3da997: Verifying Checksum
# 89633e3da997: Download complete
# 262e1eff605a: Verifying Checksum
# 262e1eff605a: Download complete
# 464e693656a9: Verifying Checksum
# 464e693656a9: Download complete
# c07bc2525035: Verifying Checksum
# c07bc2525035: Download complete
# 2747c6e3d726: Verifying Checksum
# 2747c6e3d726: Download complete
# 986eeef57cb1: Verifying Checksum
# 986eeef57cb1: Download complete
# 464e693656a9: Pull complete
# 8c578bff06c7: Pull complete
# d78f9390ce26: Pull complete
# ba3403859f87: Pull complete
# 262e1eff605a: Pull complete
# 89633e3da997: Pull complete
# 986eeef57cb1: Pull complete
# c07bc2525035: Pull complete
# 2747c6e3d726: Pull complete
# Digest: sha256:b1f72bf846c3deb803982a2e329b1500b4c796615875105986647e4c7a466f4c
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220915.v1@sha256:b1f72bf846c3deb803982a2e329b1500b4c796615875105986647e4c7a466f4c
#  ---> ec2fb4f2c94e
# Step 2/21 : USER root
#  ---> Running in e894abe76b0d
# Removing intermediate container e894abe76b0d
#  ---> 96feeb933848
# Step 3/21 : RUN mkdir -p $HOME/.cache
#  ---> Running in 80ca486ce2c4
# Removing intermediate container 80ca486ce2c4
#  ---> 2092ce66cf28
# Step 4/21 : WORKDIR /
#  ---> Running in 2cafa14776e5
# Removing intermediate container 2cafa14776e5
#  ---> c8ed1975814d
# Step 5/21 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> b9a423040373
# Step 6/21 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in a9a5003f6193
# Removing intermediate container a9a5003f6193
#  ---> 65769d1fa127
# Step 7/21 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 10c96a49792a
# Step 8/21 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 30b3420e0920
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# mkl-2021.4.0         | 219.1 MB  |            |   0%
# mkl-2021.4.0         | 219.1 MB  | 3          |   4%
# mkl-2021.4.0         | 219.1 MB  | #          |  11%
# mkl-2021.4.0         | 219.1 MB  | #7         |  18%
# mkl-2021.4.0         | 219.1 MB  | ##4        |  24%
# mkl-2021.4.0         | 219.1 MB  | ###        |  31%
# mkl-2021.4.0         | 219.1 MB  | ###7       |  38%
# mkl-2021.4.0         | 219.1 MB  | ####4      |  45%
# mkl-2021.4.0         | 219.1 MB  | #####1     |  51%
# mkl-2021.4.0         | 219.1 MB  | #####7     |  58%
# mkl-2021.4.0         | 219.1 MB  | ######4    |  65%
# mkl-2021.4.0         | 219.1 MB  | #######1   |  71%
# mkl-2021.4.0         | 219.1 MB  | #######7   |  78%
# mkl-2021.4.0         | 219.1 MB  | ########4  |  84%
# mkl-2021.4.0         | 219.1 MB  | #########  |  91%
# mkl-2021.4.0         | 219.1 MB  | #########7 |  97%
#
# mkl-2021.4.0         | 219.1 MB  | ########## | 100%
#
# libgfortran4-7.5.0   | 1.3 MB    |            |   0%
# libgfortran4-7.5.0   | 1.3 MB    | ########## | 100%
# libgfortran4-7.5.0   | 1.3 MB    | ########## | 100%
#
# numpy-base-1.23.1    | 7.1 MB    |            |   0%
# numpy-base-1.23.1    | 7.1 MB    | ########## | 100%
# numpy-base-1.23.1    | 7.1 MB    | ########## | 100%
#
# _openmp_mutex-5.1    | 20 KB     |            |   0%
# _openmp_mutex-5.1    | 20 KB     | ########## | 100%
#
# readline-8.1.2       | 423 KB    |            |   0%
# readline-8.1.2       | 423 KB    | ########## | 100%
# readline-8.1.2       | 423 KB    | ########## | 100%
#
# packaging-21.3       | 35 KB     |            |   0%
# packaging-21.3       | 35 KB     | ########## | 100%
#
# numexpr-2.8.3        | 133 KB    |            |   0%
# numexpr-2.8.3        | 133 KB    | #2         |  12%
# numexpr-2.8.3        | 133 KB    | ########## | 100%
#
# pytz-2022.1          | 243 KB    |            |   0%
# pytz-2022.1          | 243 KB    | ########## | 100%
# pytz-2022.1          | 243 KB    | ########## | 100%
#
# libstdcxx-ng-11.2.0  | 6.1 MB    |            |   0%
# libstdcxx-ng-11.2.0  | 6.1 MB    | ########## | 100%
# libstdcxx-ng-11.2.0  | 6.1 MB    | ########## | 100%
#
# ncurses-6.3          | 1.1 MB    |            |   0%
# ncurses-6.3          | 1.1 MB    | ########## | 100%
# ncurses-6.3          | 1.1 MB    | ########## | 100%
#
# openssl-1.1.1q       | 3.8 MB    |            |   0%
# openssl-1.1.1q       | 3.8 MB    | ########## | 100%
# openssl-1.1.1q       | 3.8 MB    | ########## | 100%
#
# libgcc-ng-11.2.0     | 8.5 MB    |            |   0%
# libgcc-ng-11.2.0     | 8.5 MB    | ######6    |  67%
# libgcc-ng-11.2.0     | 8.5 MB    | ########## | 100%
#
# libffi-3.3           | 54 KB     |            |   0%
# libffi-3.3           | 54 KB     | ########## | 100%
#
# setuptools-61.2.0    | 1.3 MB    |            |   0%
# setuptools-61.2.0    | 1.3 MB    | ########## | 100%
# setuptools-61.2.0    | 1.3 MB    | ########## | 100%
#
# sqlite-3.39.2        | 1.5 MB    |            |   0%
# sqlite-3.39.2        | 1.5 MB    | ########## | 100%
# sqlite-3.39.2        | 1.5 MB    | ########## | 100%
#
# pandas-1.4.3         | 12.6 MB   |            |   0%
# pandas-1.4.3         | 12.6 MB   |            |   0%
# pandas-1.4.3         | 12.6 MB   | 5          |   6%
# pandas-1.4.3         | 12.6 MB   | #          |  11%
# pandas-1.4.3         | 12.6 MB   | #5         |  16%
# pandas-1.4.3         | 12.6 MB   | ##8        |  29%
# pandas-1.4.3         | 12.6 MB   | ####       |  40%
# pandas-1.4.3         | 12.6 MB   | ######1    |  62%
# pandas-1.4.3         | 12.6 MB   | #########  |  91%
# pandas-1.4.3         | 12.6 MB   | ########## | 100%
#
# python-dateutil-2.8. | 241 KB    |            |   0%
# python-dateutil-2.8. | 241 KB    | ########## | 100%
#
# scikit-learn-1.1.1   | 8.4 MB    |            |   0%
# scikit-learn-1.1.1   | 8.4 MB    | ########## | 100%
# scikit-learn-1.1.1   | 8.4 MB    | ########## | 100%
#
# pyparsing-3.0.4      | 78 KB     |            |   0%
# pyparsing-3.0.4      | 78 KB     | ########## | 100%
#
# mkl-service-2.4.0    | 62 KB     |            |   0%
# mkl-service-2.4.0    | 62 KB     | ########## | 100%
#
# intel-openmp-2021.4. | 8.8 MB    |            |   0%
# intel-openmp-2021.4. | 8.8 MB    | ########## | 100%
# intel-openmp-2021.4. | 8.8 MB    | ########## | 100%
#
# ca-certificates-2022 | 131 KB    |            |   0%
# ca-certificates-2022 | 131 KB    | ########## | 100%
#
# wheel-0.37.1         | 31 KB     |            |   0%
# wheel-0.37.1         | 31 KB     | ########## | 100%
#
# joblib-1.1.0         | 211 KB    |            |   0%
# joblib-1.1.0         | 211 KB    | ########## | 100%
#
# six-1.16.0           | 19 KB     |            |   0%
# six-1.16.0           | 19 KB     | ########## | 100%
#
# libgomp-11.2.0       | 560 KB    |            |   0%
# libgomp-11.2.0       | 560 KB    | ########## | 100%
#
# tk-8.6.12            | 3.3 MB    |            |   0%
# tk-8.6.12            | 3.3 MB    | ########## | 100%
# tk-8.6.12            | 3.3 MB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# scipy-1.7.3          | 21.4 MB   |            |   0%
# scipy-1.7.3          | 21.4 MB   | ####5      |  46%
# scipy-1.7.3          | 21.4 MB   | ########## | 100%
# scipy-1.7.3          | 21.4 MB   | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# ld_impl_linux-64-2.3 | 732 KB    |            |   0%
# ld_impl_linux-64-2.3 | 732 KB    | ########## | 100%
# ld_impl_linux-64-2.3 | 732 KB    | ########## | 100%
#
# mkl_random-1.2.2     | 341 KB    |            |   0%
# mkl_random-1.2.2     | 341 KB    | ########## | 100%
#
# python-3.8.13        | 22.7 MB   |            |   0%
# python-3.8.13        | 22.7 MB   | ####7      |  48%
# python-3.8.13        | 22.7 MB   | ########## | 100%
# python-3.8.13        | 22.7 MB   | ########## | 100%
#
# numpy-1.23.1         | 10 KB     |            |   0%
# numpy-1.23.1         | 10 KB     | ########## | 100%
#
# bottleneck-1.3.5     | 125 KB    |            |   0%
# bottleneck-1.3.5     | 125 KB    | #2         |  13%
# bottleneck-1.3.5     | 125 KB    | ########## | 100%
#
# pip-22.1.2           | 2.9 MB    |            |   0%
# pip-22.1.2           | 2.9 MB    | ########## | 100%
# pip-22.1.2           | 2.9 MB    | ########## | 100%
#
# zlib-1.2.12          | 130 KB    |            |   0%
# zlib-1.2.12          | 130 KB    | ########## | 100%
#
# xz-5.2.5             | 389 KB    |            |   0%
# xz-5.2.5             | 389 KB    | ########## | 100%
#
# certifi-2022.6.15    | 156 KB    |            |   0%
# certifi-2022.6.15    | 156 KB    | ########## | 100%
#
# mkl_fft-1.3.1        | 200 KB    |            |   0%
# mkl_fft-1.3.1        | 200 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.5yt4rgcn.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.46.0
#   Downloading azureml_defaults-1.46.0-py3-none-any.whl (2.0 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.46.0
#   Downloading azureml_dataset_runtime-1.46.0-py3-none-any.whl (2.3 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting azureml-core~=1.46.0
#   Downloading azureml_core-1.46.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 46.9 MB/s eta 0:00:00
# Collecting azureml-inference-server-http~=0.7.2
#   Downloading azureml_inference_server_http-0.7.6-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 7.1 MB/s eta 0:00:00
# Collecting azure-mgmt-storage<=20.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-20.0.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 99.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/site-packages (from azureml-core~=1.46.0->azureml-defaults~=1.46.0->-r /azureml-environment-setup/condaenv.5yt4rgcn.requirements.txt (line 1)) (2022.1)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.2.0-py2.py3-none-any.whl (39 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 10.8 MB/s eta 0:00:00
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.10.1-py3-none-any.whl (27 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-1.0.0-py2.py3-none-any.whl (19 kB)
# Collecting pkginfo
#   Downloading pkginfo-1.8.3-py2.py3-none-any.whl (26 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/site-packages (from azureml-core~=1.46.0->azureml-defaults~=1.46.0->-r /azureml-environment-setup/condaenv.5yt4rgcn.requirements.txt (line 1)) (2.8.2)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting azure-mgmt-keyvault<11.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-10.1.0-py3-none-any.whl (605 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.9/605.9 kB 68.0 MB/s eta 0:00:00
# Collecting urllib3<2.0.0,>=1.23
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 kB 28.7 MB/s eta 0:00:00
# Collecting argcomplete<3
#   Downloading argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<38.0.0
#   Downloading cryptography-37.0.4-cp36-abi3-manylinux_2_24_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 119.2 MB/s eta 0:00:00
# Collecting jmespath<2.0.0
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting azure-mgmt-resource<22.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-21.1.0-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 106.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging<22.0,>=20.0 in /azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/site-packages (from azureml-core~=1.46.0->azureml-defaults~=1.46.0->-r /azureml-environment-setup/condaenv.5yt4rgcn.requirements.txt (line 1)) (21.3)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.5.0-py3-none-any.whl (20 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.4/141.4 kB 26.6 MB/s eta 0:00:00
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.2/146.2 kB 25.0 MB/s eta 0:00:00
# Collecting azure-mgmt-authorization<3,>=0.40.0
#   Downloading azure_mgmt_authorization-2.0.0-py2.py3-none-any.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.2/465.2 kB 53.0 MB/s eta 0:00:00
# Collecting azure-mgmt-containerregistry<11,>=8.2.0
#   Downloading azure_mgmt_containerregistry-10.0.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 96.5 MB/s eta 0:00:00
# Collecting msrest<=0.7.1,>=0.5.1
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 17.5 MB/s eta 0:00:00
# Collecting pyopenssl<23.0.0
#   Downloading pyOpenSSL-22.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 10.2 MB/s eta 0:00:00
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 12.5 MB/s eta 0:00:00
# Collecting humanfriendly<11.0,>=4.7
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 15.6 MB/s eta 0:00:00
# Collecting azure-core<2.0.0
#   Downloading azure_core-1.26.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 28.1 MB/s eta 0:00:00
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.11.0-py2.py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 34.7 MB/s eta 0:00:00
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting knack~=0.9.0
#   Downloading knack-0.9.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 10.6 MB/s eta 0:00:00
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.20.0-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 12.7 MB/s eta 0:00:00
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azureml-dataprep<4.6.0a,>=4.5.0a
#   Downloading azureml_dataprep-4.5.7-py3-none-any.whl (43.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 MB 53.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.19.3 in /azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/site-packages (from azureml-dataset-runtime[fuse]~=1.46.0->azureml-defaults~=1.46.0->-r /azureml-environment-setup/condaenv.5yt4rgcn.requirements.txt (line 1)) (1.23.1)
# Collecting pyarrow<=9.0.0,>=0.17.0
#   Downloading pyarrow-9.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 72.9 MB/s eta 0:00:00
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting flask<2.2.0
#   Downloading Flask-2.1.3-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.6/95.6 kB 14.5 MB/s eta 0:00:00
# Collecting inference-schema~=1.4.0
#   Downloading inference_schema-1.4.2.1-py3-none-any.whl (21 kB)
# Collecting flask-cors~=3.0.1
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting opencensus-ext-azure~=1.1.0
#   Downloading opencensus_ext_azure-1.1.7-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 7.2 MB/s eta 0:00:00
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/site-packages (from gunicorn==20.1.0->azureml-inference-server-http~=0.7.2->azureml-defaults~=1.46.0->-r /azureml-environment-setup/condaenv.5yt4rgcn.requirements.txt (line 1)) (61.2.0)
# Collecting typing-extensions>=4.0.1
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/site-packages (from azure-core<2.0.0->azureml-core~=1.46.0->azureml-defaults~=1.46.0->-r /azureml-environment-setup/condaenv.5yt4rgcn.requirements.txt (line 1)) (1.16.0)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.2-py3-none-any.whl (26 kB)
# Collecting azureml-dataprep-rslex~=2.11.0dev0
#   Downloading azureml_dataprep_rslex-2.11.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 100.3 MB/s eta 0:00:00
# Collecting azure-identity==1.7.0
#   Downloading azure_identity-1.7.0-py2.py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 25.4 MB/s eta 0:00:00
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp38-cp38-manylinux1_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 97.7 MB/s eta 0:00:00
# Collecting pyyaml<7.0.0,>=5.1.0
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.2/701.2 kB 69.4 MB/s eta 0:00:00
# Collecting dotnetcore2<4.0.0,>=3.0.0
#   Downloading dotnetcore2-3.1.23-py3-none-manylinux1_x86_64.whl (31.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.1/31.1 MB 75.4 MB/s eta 0:00:00
# Collecting jsonschema
#   Downloading jsonschema-4.16.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 8.8 MB/s eta 0:00:00
# Collecting cloudpickle<3.0.0,>=1.1.0
#   Downloading cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-0.3.1-py2.py3-none-any.whl (18 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.7/442.7 kB 55.9 MB/s eta 0:00:00
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.4.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.0/55.0 kB 10.7 MB/s eta 0:00:00
# Collecting importlib-metadata>=3.6.0
#   Downloading importlib_metadata-5.0.0-py3-none-any.whl (21 kB)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting Jinja2>=3.0
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 24.4 MB/s eta 0:00:00
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 33.7 MB/s eta 0:00:00
# Collecting click>=8.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 10.7 MB/s eta 0:00:00
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting pygments
#   Downloading Pygments-2.13.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 86.4 MB/s eta 0:00:00
# Collecting portalocker<3,>=1.0
#   Downloading portalocker-2.5.1-py2.py3-none-any.whl (15 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.46.0->azureml-defaults~=1.46.0->-r /azureml-environment-setup/condaenv.5yt4rgcn.requirements.txt (line 1)) (2022.6.15)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 11.2 MB/s eta 0:00:00
# Collecting opencensus<1.0.0,>=0.11.0
#   Downloading opencensus-0.11.0-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 17.5 MB/s eta 0:00:00
# Collecting psutil>=5.6.3
#   Downloading psutil-5.9.2-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (284 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.8/284.8 kB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/site-packages (from packaging<22.0,>=20.0->azureml-core~=1.46.0->azureml-defaults~=1.46.0->-r /azureml-environment-setup/condaenv.5yt4rgcn.requirements.txt (line 1)) (3.0.4)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 76.6 MB/s eta 0:00:00
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-4.0.0-cp36-abi3-manylinux_2_28_x86_64.whl (594 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.4/594.4 kB 63.9 MB/s eta 0:00:00
# Collecting pyopenssl<23.0.0
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 12.0 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 10.4 MB/s eta 0:00:00
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 8.4 MB/s eta 0:00:00
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 7.9 MB/s eta 0:00:00
# Collecting distro>=1.2.0
#   Downloading distro-1.7.0-py3-none-any.whl (20 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.8.1-py3-none-any.whl (5.6 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting opencensus-context>=0.1.3
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting google-api-core<3.0.0,>=1.0.0
#   Downloading google_api_core-2.10.2-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.6/115.6 kB 18.2 MB/s eta 0:00:00
# Collecting types-cryptography>=3.3.21
#   Downloading types_cryptography-3.3.23-py3-none-any.whl (30 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.1-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 31.0 MB/s eta 0:00:00
# Collecting importlib-resources>=1.4.0
#   Downloading importlib_resources-5.10.0-py3-none-any.whl (34 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 10.3 MB/s eta 0:00:00
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.18.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 kB 17.6 MB/s eta 0:00:00
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Downloading googleapis_common_protos-1.56.4-py2.py3-none-any.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.7/211.7 kB 5.2 MB/s eta 0:00:00
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5
#   Downloading protobuf-4.21.7-cp37-abi3-manylinux2014_x86_64.whl (408 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.4/408.4 kB 45.7 MB/s eta 0:00:00
# Collecting google-auth<3.0dev,>=1.25.0
#   Downloading google_auth-2.12.0-py2.py3-none-any.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.8/169.8 kB 31.6 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 24.1 MB/s eta 0:00:00
# Building wheels for collected packages: json-logging-py, fusepy, wrapt
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=e945407b1204b300136c40b830e969bf67b6246a659b470241753ee1e73ae1b1
#   Stored in directory: /root/.cache/pip/wheels/e9/d6/70/7491901d808e74dd9238e4a91658ba108e4b5939b55327e6fb
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=3e7d61319f2bbf7a317c957fe2e961f9bcfb27549832290fd42c715cbbec1fbd
#   Stored in directory: /root/.cache/pip/wheels/7f/41/10/f70b83a1164fdb95e7bc37bace13114a024227e56c2fee02bb
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp38-cp38-linux_x86_64.whl size=81715 sha256=b47d39a3bd2edc6411cdc462e37517bbe15794af82978af398c440c0258be5c0
#   Stored in directory: /root/.cache/pip/wheels/5f/fd/9e/b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73
# Successfully built json-logging-py fusepy wrapt
# Installing collected packages: wrapt, types-cryptography, pyasn1, opencensus-context, json-logging-py, fusepy, backports.weakref, azureml-dataprep-rslex, azureml-dataprep-native, azure-common, zipp, websocket-client, urllib3, typing-extensions, tabulate, rsa, pyyaml, PySocks, pyrsistent, PyJWT, pygments, pycparser, pyasn1-modules, pyarrow, psutil, protobuf, portalocker, pkgutil-resolve-name, pkginfo, pathspec, oauthlib, MarkupSafe, jsonpickle, jmespath, jeepney, itsdangerous, isodate, idna, humanfriendly, gunicorn, distro, contextlib2, configparser, cloudpickle, click, charset-normalizer, cachetools, bcrypt, backports.tempfile, attrs, argcomplete, Werkzeug, requests, knack, Jinja2, inference-schema, importlib-resources, importlib-metadata, googleapis-common-protos, google-auth, dotnetcore2, cffi, requests-oauthlib, pynacl, jsonschema, google-api-core, flask, docker, cryptography, azure-core, SecretStorage, pyopenssl, paramiko, opencensus, msrest, flask-cors, azure-mgmt-core, adal, ndg-httpsclient, msrestazure, msal, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, msal-extensions, azure-graphrbac, azureml-core, azure-identity, opencensus-ext-azure, azureml-dataprep, azureml-inference-server-http, azureml-dataset-runtime, azureml-defaults
# Successfully installed Jinja2-3.1.2 MarkupSafe-2.1.1 PyJWT-2.5.0 PySocks-1.7.1 SecretStorage-3.3.3 Werkzeug-2.2.2 adal-1.2.7 argcomplete-2.0.0 attrs-22.1.0 azure-common-1.1.28 azure-core-1.26.0 azure-graphrbac-0.61.1 azure-identity-1.7.0 azure-mgmt-authorization-2.0.0 azure-mgmt-containerregistry-10.0.0 azure-mgmt-core-1.3.2 azure-mgmt-keyvault-10.1.0 azure-mgmt-resource-21.1.0 azure-mgmt-storage-20.0.0 azureml-core-1.46.0 azureml-dataprep-4.5.7 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.11.4 azureml-dataset-runtime-1.46.0 azureml-defaults-1.46.0 azureml-inference-server-http-0.7.6 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-4.0.0 cachetools-5.2.0 cffi-1.15.1 charset-normalizer-2.1.1 click-8.1.3 cloudpickle-2.2.0 configparser-3.7.4 contextlib2-21.6.0 cryptography-37.0.4 distro-1.7.0 docker-5.0.3 dotnetcore2-3.1.23 flask-2.1.3 flask-cors-3.0.10 fusepy-3.0.1 google-api-core-2.10.2 google-auth-2.12.0 googleapis-common-protos-1.56.4 gunicorn-20.1.0 humanfriendly-10.0 idna-3.4 importlib-metadata-5.0.0 importlib-resources-5.10.0 inference-schema-1.4.2.1 isodate-0.6.1 itsdangerous-2.1.2 jeepney-0.8.0 jmespath-1.0.1 json-logging-py-0.2 jsonpickle-2.2.0 jsonschema-4.16.0 knack-0.9.0 msal-1.20.0 msal-extensions-0.3.1 msrest-0.7.1 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.2.1 opencensus-0.11.0 opencensus-context-0.1.3 opencensus-ext-azure-1.1.7 paramiko-2.11.0 pathspec-0.10.1 pkginfo-1.8.3 pkgutil-resolve-name-1.3.10 portalocker-2.5.1 protobuf-4.21.7 psutil-5.9.2 pyarrow-9.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.21 pygments-2.13.0 pynacl-1.5.0 pyopenssl-22.0.0 pyrsistent-0.18.1 pyyaml-6.0 requests-2.28.1 requests-oauthlib-1.3.1 rsa-4.9 tabulate-0.9.0 types-cryptography-3.3.23 typing-extensions-4.4.0 urllib3-1.26.12 websocket-client-1.4.1 wrapt-1.12.1 zipp-3.8.1
#
# done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 30b3420e0920
#  ---> 6769646da437
# Step 9/21 : ENV PATH /azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/bin:$PATH
#  ---> Running in 97e43dfbdd95
# Removing intermediate container 97e43dfbdd95
#  ---> 34264a93b1f1
# Step 10/21 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> ab949bb30087
# Step 11/21 : RUN echo "Copying environment context"
#  ---> Running in 72d610b215ec
# Copying environment context
# Removing intermediate container 72d610b215ec
#  ---> d8661b296c3d
# Step 12/21 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 57942d9b567b
# Step 13/21 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac
#  ---> Running in 63c608b877fc
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 63c608b877fc
#  ---> 3738d86815bf
# Step 14/21 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac
#  ---> Running in e55f3d555de0
# Removing intermediate container e55f3d555de0
#  ---> caf2375803fd
# Step 15/21 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib:$LD_LIBRARY_PATH
#  ---> Running in 3c34cf81b2ec
# Removing intermediate container 3c34cf81b2ec
#  ---> 0c9dad0dff93
# Step 16/21 : ENV CONDA_DEFAULT_ENV=azureml_c24d2aa9d2a47b6687cc1ba0963dfdac CONDA_PREFIX=/azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac
#  ---> Running in 7a43e0157093
# Removing intermediate container 7a43e0157093
#  ---> 75914b660e80
# Step 17/21 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> d679a20f5646
# Step 18/21 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 36ba963c3d4f
# Removing intermediate container 36ba963c3d4f
#  ---> 6925c98f1fc4
# Step 19/21 : RUN rm -rf azureml-environment-setup
#  ---> Running in e4baec164e5f
# Removing intermediate container e4baec164e5f
#  ---> 121be67eeb3b
# Step 20/21 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 3202e5a03267
# Removing intermediate container 3202e5a03267
#  ---> 85ab9440c239
# Step 21/21 : CMD ["bash"]
#  ---> Running in 40f71301b175
# Removing intermediate container 40f71301b175
#  ---> 46a9acd094f6
# Successfully built 46a9acd094f6
# Successfully tagged 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io/azureml/azureml_0cb1a0325cdf40d20f0f724c6bb5a6a4:latest
# Successfully tagged 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io/azureml/azureml_0cb1a0325cdf40d20f0f724c6bb5a6a4:1
# 2022/10/08 06:53:30 Successfully executed container: acb_step_0
# 2022/10/08 06:53:30 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/10/08 06:53:30 Pushing image: 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io/azureml/azureml_0cb1a0325cdf40d20f0f724c6bb5a6a4:1, attempt 1
# The push refers to repository [27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io/azureml/azureml_0cb1a0325cdf40d20f0f724c6bb5a6a4]
# bc1694b3dffe: Preparing
# c95cb2cfbcaa: Preparing
# 8b36a9fa4a63: Preparing
# 0e7cd841aeea: Preparing
# 94fdc516bb44: Preparing
# e837bb9f2f13: Preparing
# 3d3cca5514f5: Preparing
# fe5ca9cce095: Preparing
# ce823be1fba3: Preparing
# 06e248957fb4: Preparing
# 4f5029a9dd35: Preparing
# d97a0d4cdf00: Preparing
# 94f2f8deda61: Preparing
# c52612c14feb: Preparing
# 5db58646e2f5: Preparing
# 4dbf5f708d91: Preparing
# 339cc9230658: Preparing
# 65cb687f36fa: Preparing
# d1210ad29f1f: Preparing
# af7ed92504ae: Preparing
# e837bb9f2f13: Waiting
# 3d3cca5514f5: Waiting
# fe5ca9cce095: Waiting
# ce823be1fba3: Waiting
# 06e248957fb4: Waiting
# 4f5029a9dd35: Waiting
# d97a0d4cdf00: Waiting
# 94f2f8deda61: Waiting
# c52612c14feb: Waiting
# 5db58646e2f5: Waiting
# 4dbf5f708d91: Waiting
# 339cc9230658: Waiting
# 65cb687f36fa: Waiting
# d1210ad29f1f: Waiting
# af7ed92504ae: Waiting
# 0e7cd841aeea: Pushed
# 94fdc516bb44: Pushed
# c95cb2cfbcaa: Pushed
# bc1694b3dffe: Pushed
# 8b36a9fa4a63: Pushed
# 3d3cca5514f5: Pushed
# ce823be1fba3: Pushed
# fe5ca9cce095: Pushed
# 06e248957fb4: Pushed
# 4f5029a9dd35: Pushed
# d97a0d4cdf00: Pushed
# 4dbf5f708d91: Pushed
# c52612c14feb: Pushed
# 94f2f8deda61: Pushed
# 339cc9230658: Pushed
# 65cb687f36fa: Pushed
# 5db58646e2f5: Pushed
# af7ed92504ae: Pushed
#
# d1210ad29f1f: Pushed
#
# e837bb9f2f13: Pushed
# 1: digest: sha256:c4581afc538c14828d12c2be16d04b9eadff42786c12e017f733825b366609b3 size: 4513
# 2022/10/08 06:55:18 Successfully pushed image: 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io/azureml/azureml_0cb1a0325cdf40d20f0f724c6bb5a6a4:1
# 2022/10/08 06:55:18 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/10/08 06:55:18 Pushing image: 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io/azureml/azureml_0cb1a0325cdf40d20f0f724c6bb5a6a4:latest, attempt 1
# The push refers to repository [27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io/azureml/azureml_0cb1a0325cdf40d20f0f724c6bb5a6a4]
# bc1694b3dffe: Preparing
# c95cb2cfbcaa: Preparing
# 8b36a9fa4a63: Preparing
# 0e7cd841aeea: Preparing
# 94fdc516bb44: Preparing
# e837bb9f2f13: Preparing
# 3d3cca5514f5: Preparing
# fe5ca9cce095: Preparing
# ce823be1fba3: Preparing
# 06e248957fb4: Preparing
# 4f5029a9dd35: Preparing
# d97a0d4cdf00: Preparing
# 94f2f8deda61: Preparing
# c52612c14feb: Preparing
# 5db58646e2f5: Preparing
# 4dbf5f708d91: Preparing
# 339cc9230658: Preparing
# 65cb687f36fa: Preparing
# d1210ad29f1f: Preparing
# af7ed92504ae: Preparing
# e837bb9f2f13: Waiting
# 3d3cca5514f5: Waiting
# fe5ca9cce095: Waiting
# ce823be1fba3: Waiting
# 06e248957fb4: Waiting
# 4f5029a9dd35: Waiting
# d97a0d4cdf00: Waiting
# 94f2f8deda61: Waiting
# c52612c14feb: Waiting
# 5db58646e2f5: Waiting
# 4dbf5f708d91: Waiting
# 339cc9230658: Waiting
# 65cb687f36fa: Waiting
# d1210ad29f1f: Waiting
# af7ed92504ae: Waiting
# 94fdc516bb44: Layer already exists
# c95cb2cfbcaa: Layer already exists
# 3d3cca5514f5: Layer already exists
# e837bb9f2f13: Layer already exists
# 0e7cd841aeea: Layer already exists
# fe5ca9cce095: Layer already exists
# ce823be1fba3: Layer already exists
# bc1694b3dffe: Layer already exists
# 8b36a9fa4a63: Layer already exists
# 06e248957fb4: Layer already exists
# 94f2f8deda61: Layer already exists
# d97a0d4cdf00: Layer already exists
# c52612c14feb: Layer already exists
# 4dbf5f708d91: Layer already exists
# 5db58646e2f5: Layer already exists
# 4f5029a9dd35: Layer already exists
# 65cb687f36fa: Layer already exists
# 339cc9230658: Layer already exists
# d1210ad29f1f: Layer already exists
# af7ed92504ae: Layer already exists
# latest: digest: sha256:c4581afc538c14828d12c2be16d04b9eadff42786c12e017f733825b366609b3 size: 4513
# 2022/10/08 06:55:20 Successfully pushed image: 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io/azureml/azureml_0cb1a0325cdf40d20f0f724c6bb5a6a4:latest
# 2022/10/08 06:55:20 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 238.403186)
# 2022/10/08 06:55:20 Populating digests for step ID: acb_step_0...
# 2022/10/08 06:55:22 Successfully populated digests for step ID: acb_step_0
# 2022/10/08 06:55:22 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 107.694277)
# 2022/10/08 06:55:22 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 2.560707)
# 2022/10/08 06:55:22 The following dependencies were found:
# 2022/10/08 06:55:22
# - image:
#     registry: 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io
#     repository: azureml/azureml_0cb1a0325cdf40d20f0f724c6bb5a6a4
#     tag: latest
#     digest: sha256:c4581afc538c14828d12c2be16d04b9eadff42786c12e017f733825b366609b3
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20220915.v1
#     digest: sha256:b1f72bf846c3deb803982a2e329b1500b4c796615875105986647e4c7a466f4c
#   git: {}
# - image:
#     registry: 27bbdeda49d14f8b9a7571d17bc330d8.azurecr.io
#     repository: azureml/azureml_0cb1a0325cdf40d20f0f724c6bb5a6a4
#     tag: "1"
#     digest: sha256:c4581afc538c14828d12c2be16d04b9eadff42786c12e017f733825b366609b3
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20220915.v1
#     digest: sha256:b1f72bf846c3deb803982a2e329b1500b4c796615875105986647e4c7a466f4c
#   git: {}
#
# Run ID: ce7 was successful after 5m54s
# StepRun(Evaluate) Execution Summary
# ====================================
# StepRun( Evaluate ) Status: Failed
#
# Warnings:
# AzureMLCompute job failed.
# ExecutionFailed: [REDACTED]
# 	exit_codes: 1
# {"NonCompliant":"Process '/azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/bin/python' exited with code 1 and error message 'Execution failed. Process exited with status code 1. Error: Traceback (most recent call last):\n  File \"630 - Evaluate.py\"
# ---------------------------------------------------------------------------
# ActivityFailedException                   Traceback (most recent call last)
# <ipython-input-104-1fc28ac2aa3f> in <module>
#      26
#      27 # Wait for completion
# ---> 28 new_pipeline_run.wait_for_completion(show_output=True)
#
# ~\Anaconda3\lib\site-packages\azureml\pipeline\core\run.py in wait_for_completion(self, show_output, timeout_seconds, raise_on_error)
#     293                             print('\n')
#     294                             try:
# --> 295                                 step_run.wait_for_completion(timeout_seconds=timeout_seconds - time_elapsed,
#     296                                                              raise_on_error=raise_on_error)
#     297                             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\azureml\pipeline\core\run.py in wait_for_completion(self, show_output, timeout_seconds, raise_on_error)
#     736         if show_output:
#     737             try:
# --> 738                 return self._stream_run_output(timeout_seconds=timeout_seconds,
#     739                                                raise_on_error=raise_on_error)
#     740             except KeyboardInterrupt:
#
# ~\Anaconda3\lib\site-packages\azureml\pipeline\core\run.py in _stream_run_output(self, timeout_seconds, raise_on_error)
#     829             print(json.dumps(error, indent=4))
#     830         if error and raise_on_error:
# --> 831             raise ActivityFailedException(error_details=json.dumps(error, indent=4))
#     832
#     833         print(final_details)
#
# ActivityFailedException: ActivityFailedException:
# 	Message: Activity Failed:
# {
#     "error": {
#         "code": "UserError",
#         "message": "{\"NonCompliant\":\"Process '/azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/bin/python' exited with code 1 and error message 'Execution failed. Process exited with status code 1. Error: Traceback (most recent call last):\\n  File \\\"630 - Evaluate.py\\\", line 44, in <module>\\n    rfc = joblib.load(obj_file)\\n  File \\\"/azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/site-packages/joblib/numpy_pickle.py\\\", line 587, in load\\n    obj = _unpickle(fobj, filename, mmap_mode)\\n  File \\\"/azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/site-packages/joblib/numpy_pickle.py\\\", line 506, in _unpickle\\n    obj = unpickler.load()\\n  File \\\"/azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/pickle.py\\\", line 1212, in load\\n    dispatch[key[0]](self)\\n  File \\\"/azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/pickle.py\\\", line 1528, in load_global\\n    klass = self.find_class(module, name)\\n  File \\\"/azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/pickle.py\\\", line 1579, in find_class\\n    __import__(module, level=0)\\nModuleNotFoundError: No module named 'sklearn.ensemble.forest'\\n\\n'. Please check the log file 'user_logs/std_log.txt' for more details.\"}\n{\n  \"code\": \"ExecutionFailed\",\n  \"target\": \"\",\n  \"category\": \"UserError\",\n  \"error_details\": [\n    {\n      \"key\": \"exit_codes\",\n      \"value\": \"1\"\n    }\n  ]\n}",
#         "messageParameters": {},
#         "details": []
#     },
#     "time": "0001-01-01T00:00:00.000Z"
# }
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Activity Failed:\n{\n    \"error\": {\n        \"code\": \"UserError\",\n        \"message\": \"{\\\"NonCompliant\\\":\\\"Process '/azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/bin/python' exited with code 1 and error message 'Execution failed. Process exited with status code 1. Error: Traceback (most recent call last):\\\\n  File \\\\\\\"630 - Evaluate.py\\\\\\\", line 44, in <module>\\\\n    rfc = joblib.load(obj_file)\\\\n  File \\\\\\\"/azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/site-packages/joblib/numpy_pickle.py\\\\\\\", line 587, in load\\\\n    obj = _unpickle(fobj, filename, mmap_mode)\\\\n  File \\\\\\\"/azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/site-packages/joblib/numpy_pickle.py\\\\\\\", line 506, in _unpickle\\\\n    obj = unpickler.load()\\\\n  File \\\\\\\"/azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/pickle.py\\\\\\\", line 1212, in load\\\\n    dispatch[key[0]](self)\\\\n  File \\\\\\\"/azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/pickle.py\\\\\\\", line 1528, in load_global\\\\n    klass = self.find_class(module, name)\\\\n  File \\\\\\\"/azureml-envs/azureml_c24d2aa9d2a47b6687cc1ba0963dfdac/lib/python3.8/pickle.py\\\\\\\", line 1579, in find_class\\\\n    __import__(module, level=0)\\\\nModuleNotFoundError: No module named 'sklearn.ensemble.forest'\\\\n\\\\n'. Please check the log file 'user_logs/std_log.txt' for more details.\\\"}\\n{\\n  \\\"code\\\": \\\"ExecutionFailed\\\",\\n  \\\"target\\\": \\\"\\\",\\n  \\\"category\\\": \\\"UserError\\\",\\n  \\\"error_details\\\": [\\n    {\\n      \\\"key\\\": \\\"exit_codes\\\",\\n      \\\"value\\\": \\\"1\\\"\\n    }\\n  ]\\n}\",\n        \"messageParameters\": {},\n        \"details\": []\n    },\n    \"time\": \"0001-01-01T00:00:00.000Z\"\n}"
#     }
# }

# %%
# Databricks stepのアウトプットはDatabricksのrunから確認したrun_IDのフォルダ名の中に格納されている
# --AZUREML_RUN_ID 5192c843-7a9c-4c25-be32-8e48da275e39
